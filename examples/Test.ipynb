# %%
# /// script
# requires-python = "~=3.12.0"
# dependencies = [
#   "cowsay>=6.1",
#   "numpy>=2.3.1",
#   "pint>=0.24.4",
#   "requests",
#   "rich",
# ]
# ///

# %%
import requests

Hello I am Changing Things
